# %%
import pandas as pd
import numpy as np
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Lendo os dados
temer = pd.read_csv('003.temer/votacao.temer.csv')

# %%
temer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 9 columns):
# dep          513 non-null object
# partido      513 non-null object
# estado       513 non-null object
# votodilma    513 non-null object
# liberado     513 non-null float64
# recebido     513 non-null float64
# vototemer    511 non-null object
# discurso     488 non-null object
# discurso2    513 non-null int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 36.1+ KB

# %%
#Alterando a quantidade de linhas exibidas após o código rodar
pd.set_option('display.max_rows', 550)

# %%
#Quantidade de palavras no discurso dos deputados
print temer.discurso2.sort_values()
discurso2 = temer.discurso2
print temer.dep.sort_values()
# Out:
# 62       0
# 126      0
# 317      0
# 141      0
# 122      0
# 440      0
# 342      0
# 343      0
# 437      0
# 20       0
# 435      0
# 426      0
# 318      0
# 486      0
# 370      0
# 396      0
# 1        0
# 225      0
# 405      0
# 501      0
# 379      0
# 233      0
# 456      0
# 188      0
# 187      0
# 264      1
# 144      1
# 109      1
# 186      1
# 199      2
# 380      2
# 415      2
# 462      2
# 357      3
# 220      3
# 228      3
# 146      3
# 296      3
# 294      3
# 129      3
# 413      4
# 223      4
# 209      4
# 255      4
# 179      4
# 422      4
# 178      4
# 31       4
# 166      4
# 148      4
# 119      4
# 313      4
# 38       4
# 37       4
# 326      4
# 349      4
# 358      5
# 163      5
# 365      5
# 90       5
# 180      5
# 78       5
# 282      5
# 347      5
# 19       5
# 470      5
# 297      6
# 328      6
# 329      6
# 271      6
# 423      6
# 340      6
# 43       6
# 353      6
# 172      6
# 287      7
# ...

# %%
#Deputados com mais dinheiro para emendas liberado por Temer
temer.sort_values('liberado', ascending=False)
# Out:
#                                    dep partido estado            votodilma  \
# 318                     Marcelo Castro    PMDB     PI               Contra
# 456                           Shéridan    PSDB     RR              A favor
# 133                      Domingos Neto     PSD     CE               Contra
# 491                        Vitor Valim    PMDB     CE              A favor
# 74                        Bruno Araújo    PSDB     PE              A favor
# 186                            Giacobo      PR     PR              A favor
# 461                       Simão Sessim      PP     RJ              A favor
# 76                         Cabo Sabino      PR     CE              A favor
# 58                             Bacelar    PODE     BA               Contra
# 24                      Alice Portugal   PCdoB     BA               Contra
# 27                      Aluisio Mendes    PODE     MA               Contra
# ...

# %%
#Deputados com menos dinheiro para emendas liberado por Temer
temer.sort_values('liberado', ascending=True)
# Out:
#                                    dep partido estado            votodilma  \
# 432                      Rogério Silva    PMDB     MT  Não estava no cargo
# 343                 Mauricio Quintella      PR     AL              A favor
# 458                       Silas Freire    PODE     PI  Não estava no cargo
# 455                     Sergio Zveiter    PMDB     RJ              A favor
# 281                  Leonardo Picciani    PMDB     RJ               Contra
# 282                   Leonardo Quintão    PMDB     MG              A favor
# 452                        Sérgio Reis     PRB     SP              A favor
# 342                       Marx Beltrão    PMDB     AL              A favor
# 287                         Lobbe Neto    PSDB     SP  Não estava no cargo
# 449                 Sebastião Oliveira      PR     PE            abstenção
# 128                   Deoclides Macedo     PDT     MA  Não estava no cargo
# ...

# %%
temer.partido.value_counts()
# Out:
# PMDB     63
# PT       58
# PSDB     47
# PP       47
# PR       40
# PSD      38
# PSB      35
# DEM      31
# PRB      22
# PTB      18
# PDT      18
# PODE     14
# SD       14
# PSC      10
# PPS      10
# PCdoB    10
# PV        7
# PHS       7
# PSOL      6
# PROS      4
# Rede      4
# PTdoB     3
# PSL       3
# PEN       3
# PMB       1
# Name: partido, dtype: int64
